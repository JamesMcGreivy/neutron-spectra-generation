# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from sklearn.model_selection import ShuffleSplit
from tensorflow.keras.callbacks import EarlyStopping
from bayes_opt import BayesianOptimization
from bayes_opt.logger import JSONLogger
from bayes_opt.event import Events
from tensorflow.keras.optimizers import Adam
from sklearn import metrics
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.style.use('seaborn')
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

import sys
sys.path.append("/g/g15/mcgreivy/NeutronSpectraGeneration/")

import unfolding_network
import data_generation
import constants

# %%
meanPeakCenter = 0.75
stdPeakCenter = 0
meanPeakWidth = 0.15
stdPeakWidth = 0
extraPeakProb = 0.01
ampDecay = 1
widthToAmp = 0

x, y = data_generation.gaussian_peak_algorithm(meanPeakCenter, stdPeakCenter, meanPeakWidth, 
                          stdPeakWidth, extraPeakProb, ampDecay, widthToAmp)

# %%
plt.plot(constants.Ebins, y[0])
plt.xscale("log")

# %%
def evaluate_GPA_params(meanPeakCenter, stdPeakCenter, meanPeakWidth, 
                      stdPeakWidth, extraPeakProb, ampDecay, ampSpread):
    
    lr = 0.001
    
    SPLITS = 4
    benchmark = []

    xeval, yeval = data_generation.x_data_IAEA, data_generation.y_data_IAEA
    
    for _ in range(SPLITS):
        
        xdata, ydata = data_generation.gaussian_peak_algorithm(meanPeakCenter, stdPeakCenter, meanPeakWidth, 
                          stdPeakWidth, extraPeakProb, ampDecay, ampSpread,
                          numData = 3000)

        w = np.matmul(np.matmul(np.linalg.inv(np.matmul(xdata.T, xdata)), xdata.T), ydata)
        
        ypred = np.matmul(xeval, w)
        
        score = metrics.mean_squared_error(yeval, ypred)
        benchmark.append(score)
        
    print("{} ± {}".format(np.mean(benchmark), 2 * np.std(benchmark)))
        
    return -1e6 * np.mean(benchmark)

pbounds = {"ampDecay" : (0.3, 1),
           "extraPeakProb" : (0.5, 0.95),
           "meanPeakCenter" : (0, 1),
           "meanPeakWidth" : (0, 0.2),
           "stdPeakCenter" : (0, 0.5),
           "stdPeakWidth" : (0, 0.1),
           "widthToAmp" : (0, 10)}

def optimize_model(init_points = 100, n_iter = 100):    

    optimizer = BayesianOptimization(f = evaluate_GPA_params,
                                    pbounds = pbounds,
                                    verbose = 2)

    optimizer.maximize(init_points = init_points, n_iter = n_iter)

    return optimizer.max

# %%
optimize_model()
# Out:
# |   iter    |  target   | ampDecay  | extraP... | meanPe... | meanPe... | stdPea... | stdPea... | widthT... |
# -------------------------------------------------------------------------------------------------------------
# 0.0002930528158381992 ± 0.00010667725538825538
# |  1        | -293.1    |  0.9633   |  0.7475   |  0.9473   |  0.03856  |  0.3231   |  0.01786  |  6.703    |
# 0.011784476475506282 ± 0.01053131757422991
# |  2        | -1.178e+0 |  0.4902   |  0.9194   |  0.03743  |  0.07095  |  0.2558   |  0.05814  |  9.856    |
# 0.00025608439288809885 ± 3.791203066451573e-05
# |  3        | -256.1    |  0.7846   |  0.9064   |  0.1446   |  0.04005  |  0.4454   |  0.02418  |  9.575    |
# 0.0002811705349235016 ± 4.0942271042458235e-05
# |  4        | -281.2    |  0.4479   |  0.7033   |  0.7146   |  0.06532  |  0.3052   |  0.02857  |  2.279    |
# 0.0013746639102179001 ± 0.00247259615185252
# |  112      | -1.375e+0 |  0.6911   |  0.95     |  0.0      |  0.2      |  0.5      |  0.1      |  0.3266   |
# 1.0190470269461134 ± 3.5163997406529344
# |  113      | -1.019e+0 |  0.3      |  0.95     |  1.0      |  0.2      |  0.5      |  0.0      |  10.0     |
# 0.028767069963044296 ± 0.022810048806238478
# |  114      | -2.877e+0 |  1.0      |  0.95     |  1.0      |  0.0      |  0.0      |  0.1      |  2.746    |
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/workspace/mcgreivy/opence/lib/python3.7/site-packages/bayes_opt/target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (0.3, 0.5, 1.0, 0.0, 0.5, 0.0, 6.2119601573194645)
#
# During handling of the above exception, another exception occurred:
#
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-5-f49ba3ccc7e2> in <module>
# ----> 1 optimize_model()
#
# <ipython-input-4-6aadb0992787> in optimize_model(init_points, n_iter)
#      40                                     verbose = 2)
#      41
# ---> 42     optimizer.maximize(init_points = init_points, n_iter = n_iter)
#      43
#      44     return optimizer.max
#
# /usr/workspace/mcgreivy/opence/lib/python3.7/site-packages/bayes_opt/bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     183                 iteration += 1
#     184
# --> 185             self.probe(x_probe, lazy=False)
#     186
#     187             if self._bounds_transformer:
#
# /usr/workspace/mcgreivy/opence/lib/python3.7/site-packages/bayes_opt/bayesian_optimization.py in probe(self, params, lazy)
#     114             self._queue.add(params)
#     115         else:
# --> 116             self._space.probe(params)
#     117             self.dispatch(Events.OPTIMIZATION_STEP)
#     118
#
# /usr/workspace/mcgreivy/opence/lib/python3.7/site-packages/bayes_opt/target_space.py in probe(self, params)
#     192         except KeyError:
#     193             params = dict(zip(self._keys, x))
# --> 194             target = self.target_func(**params)
#     195             self.register(x, target)
#     196         return target
#
# <ipython-input-4-6aadb0992787> in evaluate_GPA_params(meanPeakCenter, stdPeakCenter, meanPeakWidth, stdPeakWidth, extraPeakProb, ampDecay, widthToAmp)
#      15                           numData = 3000)
#      16
# ---> 17         w = np.matmul(np.matmul(np.linalg.inv(np.matmul(xdata.T, xdata)), xdata.T), ydata)
#      18
#      19         ypred = np.matmul(xeval, w)
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# /usr/workspace/mcgreivy/opence/lib/python3.7/site-packages/numpy/linalg/linalg.py in inv(a)
#     538     """
#     539     a, wrap = _makearray(a)
# --> 540     _assert_stacked_2d(a)
#     541     _assert_stacked_square(a)
#     542     t, result_t = _commonType(a)
#
# /usr/workspace/mcgreivy/opence/lib/python3.7/site-packages/numpy/linalg/linalg.py in _assert_stacked_2d(*arrays)
#     196         if a.ndim < 2:
#     197             raise LinAlgError('%d-dimensional array given. Array must be '
# --> 198                     'at least two-dimensional' % a.ndim)
#     199
#     200 def _assert_stacked_square(*arrays):
#
# LinAlgError: 0-dimensional array given. Array must be at least two-dimensional

# %%
np.random.random()
# Out:
# 0.43318658169277513
